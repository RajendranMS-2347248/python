# %%
Q1. Create two 3×3 matrices using the random function in Numpy and perform the following operations.
è Product (prod)
è Multiplication (multiply)
è Dot Product (dot)

# %% [markdown]
# import numpy as np
#
# A = np.random.randint(0,9,size=(3,3),dtype=int)
# B = np.random.randint(0,9,size=(3,3),dtype=int)
#
# print(A)
#
# print(B)
#
#
# A*B

# %%
np.multiply(A,B)
# Out:
# array([[ 2,  0,  6],
#        [ 6, 42,  0],
#        [15,  0, 15]])

# %%
Q2. Perform the following set operations using the Numpy functions.
è Union
è Intersection
è Set difference
è XOR

# %% [markdown]
# np.dot(A,B)

# %%
C=np.random.randint(0,9,size=(1,4),dtype=int)
D=np.random.randint(0,9,size=(1,4),dtype=int)

print(C)
print(D)

union=np.union1d(C,D)
print(union)
# Out:
# [[0 1 8 8]]
# [[2 3 3 3]]
# [0 1 2 3 8]

# %%
inter=np.intersect1d(C,D)
print(inter)
# Out:
# []

# %%
dif=np.setdiff1d(C,D)
print(diff)
# Out:
# [0 1 8]

# %%
x=np.setxor1d(C,D)
print(x)
# Out:
# [0 1 2 3 8]

# %% [markdown]
# Q3. Create a 1D array using Random function and perform the following operations.
# è Cumulative sum
# è Cumulative Product
# è Discrete difference (with n=3)
# è Find the unique elements from the array

# %%
E=np.random.randint(0,9,size=(1,8),dtype=int)


a=np.cumsum(E)
print(a)
# Out:
# [ 7 11 12 19 25 32 40 47]

# %%
b=np.cumprod(E)

print(b)
# Out:
# [     5     30    210    840   2520  20160  80640 564480]

# %%
c=np.diff(E,n=3)
print(c)
# Out:
# [[ -4   6   4 -15  16]]

# %%
d=np.unique(E)
print(d)

# %% [markdown]
# Q4. Create two 1D array and perform the Addition using zip(), add() and user defined function (frompyfunc())

# %%
F=np.random.randint(0,9,size=(1,8),dtype=int)
G=np.random.randint(0,9,size=(1,8),dtype=int)

rezip=[x+y for x,y in zip(F,G)]

readd=np.add(F,G)

addfunct=np.frompyfunc(lambda x,y : x + y,2,1)
rescust= addfunct(F,G)

print(F)
print(G)
print("Using zip():",rezip)
print("using add():",readd)
print("using addfunct():",addfunct)
print("using rescust():",rescust)
# Out:
# [[8 7 4 2 5 3 8 6]]
# [[8 6 0 4 8 7 5 3]]
# Using zip(): [array([16, 13,  4,  6, 13, 10, 13,  9])]
# using add(): [[16 13  4  6 13 10 13  9]]
# using addfunct(): <ufunc '<lambda> (vectorized)'>
# using rescust(): [[16 13 4 6 13 10 13 9]]

# %%
from functools import reduce
import math

def lcm(x,y):
    return x*y // math.gcd(x,y)

def gcd(x,y):
    return math.gcd(x,y)

arr=[12,18,124,36]

lcmres=reduce(lcm,arr)
gcdres=reduce(gcd,arr)

print("Array: ", arr)
print("LCM: ",lcmres)
print("GCD: ",gcdres)
# Out:
# Array:  [12, 18, 124, 36]
# LCM:  1116
# GCD:  2
